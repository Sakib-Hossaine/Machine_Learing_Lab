# %%
import matplotlib.pyplot as plt

# %%
x=["python","java", "c++"]
y=[85, 70 ,60]
plt.bar(x,y)
plt.show()

# %%
x=["python","java", "c++"]
y=[85, 70 ,60]
c=["y","b","g"]
plt.bar(x,y,width=0.4,color=c,align= "edge")

plt.xlabel("programming language",fontsize=11)
plt.ylabel("No.")
plt.title("Performance")
plt.show()

# %%
x=["python","java", "c++"]
y=[85, 70 ,60]
Z=[20,30,40]
plt.bar(x,y,width=0.4,color="r",label="popularity")
plt.bar(x,Z,width=0.4,color="b",label="popularity1")
plt.xlabel("programming language",fontsize=11)
plt.ylabel("No.")
plt.title("Performance")
plt.show()

# %%
import numpy as np

# %%
x=["python","java", "c++"]
y=[85, 70 ,60]
Z=[20,30,40]
p=np.arange(len(x))
plt.bar(p,y,width=0.4,color="r",label="popularity")
plt.bar(p,Z,width=0.4,color="b",label="popularity1")
plt.xlabel("programming language",fontsize=11)
plt.ylabel("No.")
plt.title("Performance")
plt.show()

# %%
x=["python","java", "c++"]
y=[85, 70 ,60]
Z=[20,30,40]

p=np.arange(len(x))
p1=[i+0.4 for i in p]

plt.bar(p,y,width=0.4,color="r",label="popularity")
plt.bar(p1,Z,width=0.4,color="b",label="popularity1")

plt.xlabel("programming language",fontsize=11)
plt.ylabel("No.")
plt.title("Performance")
plt.show()

# %%
x=["python","java", "c++"]
y=[85, 70 ,60]
Z=[20,30,40]

p=np.arange(len(x))
p1=[i+0.4 for i in p]

plt.bar(p,y,width=0.4,color="r",label="popularity")
plt.bar(p1,Z,width=0.4,color="b",label="popularity1")

plt.xlabel("programming language",fontsize=11)
plt.ylabel("No.")
plt.title("Performance")

plt.xticks(p+0.2,x,rotation=10)
plt.show()

# %%
day= [1,2,3,4,5,6,7,7,8,9]
no= [2,3,4,5,6,7,8,9,1,2]
plt.scatter(day,no)
plt.title("Scatter plot")
plt.xlabel("Day")
plt.ylabel("No.")
plt.show()

# %%
import random

# %%
x= np.random.randint(10, 60,(50))
print(x)
# Out:
# [57 54 28 29 42 22 36 38 10 14 34 18 56 59 22 47 22 18 18 18 17 24 34 44
#  23 51 27 45 41 51 24 39 48 27 57 14 40 16 35 52 39 45 42 45 55 54 56 45
#  24 28]

# %%
no=[44, 19, 31, 49, 12, 53, 23, 19, 54, 37, 19, 15, 14, 43, 55, 30, 44, 10, 22, 35, 35, 13, 50, 45,
 26, 51, 39, 40, 47, 13, 41, 27, 20, 27, 15, 51, 22, 41, 13, 14, 21, 37, 42, 57, 48, 17, 16, 12,
 44, 33]
l=[10, 20, 30, 40, 50, 60]
plt.hist(no,edgecolor="black",bins=l)
plt.show()

# %%
no=[44, 19, 31, 49, 12, 53, 23, 19, 54, 37, 19, 15, 14, 43, 55, 30, 44, 10, 22, 35, 35, 13, 50, 45,
 26, 51, 39, 40, 47, 13, 41, 27, 20, 27, 15, 51, 22, 41, 13, 14, 21, 37, 42, 57, 48, 17, 16, 12,
 44, 33]
l=[10, 20, 30, 40, 50, 60]
plt.hist(no,edgecolor="black",bins="auto",range=(0,200))
plt.show()

# %%
no=[44, 19, 31, 49, 12, 53, 23, 19, 54, 37, 19, 15, 14, 43, 55, 30, 44, 10, 22, 35, 35, 13, 50, 45,
 26, 51, 39, 40, 47, 13, 41, 27, 20, 27, 15, 51, 22, 41, 13, 14, 21, 37, 42, 57, 48, 17, 16, 12,
 44, 33]
l=[10, 20, 30, 40, 50, 60]
plt.hist(no,edgecolor="black",bins="auto",log=True)
plt.grid()
plt.show()

# %%
x= [20, 20,10,30,20]
y=["python","java","c++","c#","ruby"]
plt.pie(x,labels=y,autopct="%1.2f%%",explode=[0.1,0.1,0,0,0],shadow=True,startangle=90)
plt.show()

# %%
x= [20, 20,10,30,20]
y=["python","java","c++","c#","ruby"]
plt.pie(x,labels=y,autopct="%1.2f%%",explode=[0.1,0.1,0,0,0],shadow=True,startangle=90, textprops={'fontsize': 10})
plt.show()

# %%
x= [20, 20,10,30,20]
y=["python","java","c++","c#","ruby"]
plt.pie(x,labels=y,autopct="%1.2f%%",explode=[0.1,0.1,0,0,0],shadow=True,startangle=90, textprops={'fontsize': 10}) 
plt.show()

# %%
x= [20, 20,10,30,20]
y=["python","java","c++","c#","ruby"]
plt.pie(x,labels=y,autopct="%1.2f%%",explode=[0.1,0.1,0,0,0],shadow=True,startangle=90, textprops={'fontsize': 10},wedgeprops={"edgecolor":"black","linewidth":1}) 
plt.show()

# %%
x= [20, 20,10,30,20]
y=["python","java","c++","c#","ruby"]
plt.pie(x,labels=y,autopct="%1.2f%%",explode=[0.1,0.1,0,0,0],shadow=True,startangle=90, textprops={'fontsize': 10},wedgeprops={"edgecolor":"black","linewidth":1}, center=(0.5,0.5), radius=1.2)
plt.show()

# %%
x= [20, 20,10,30,20]
y=["python","java","c++","c#","ruby"]
plt.pie(x,labels=y,autopct="%1.2f%%",explode=[0.1,0.1,0,0,0],shadow=True,startangle=90, textprops={'fontsize': 10},wedgeprops={"edgecolor":"black","linewidth":1}, center=(0.5,0.5), radius=1.2)
plt.legend(title="Languages",loc="upper right")
plt.show()
